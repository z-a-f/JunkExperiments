# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import torch
from torch import nn
import torch.nn.functional as F

import torch.quantization as tq
from torch.nn import quantized as nnq

# %%
def quantize(x, dtype):
    iinfo = torch.iinfo(dtype)
    qmin = iinfo.min
    qmax = iinfo.max
    fmin = min(0, x.min().item())
    fmax = max(0, x.max().item())
    
    if fmin == fmax:
        fdiff = 1.0
    else:
        fdiff = (fmax - fmin)
    
    scale = fdiff / (qmax - qmin)
    zp = int(round(qmin - fmin / scale))
    qx = torch.quantize_per_tensor(x, scale=scale, zero_point=zp, dtype=dtype)
    return qx

def SNR(x, qx):
    if qx.is_quantized:
        qx = qx.dequantize()
    noise = ((x - qx)**2).mean().item()
    signal = x.square().mean().item()
    snr = signal / noise
    snr_db = 10 * np.log10(snr)
    return snr, snr_db

# %%
from pose_mobilenet import get_pose_net

model = get_pose_net(is_train=False)
model.eval()
model.fuse_model()
model.qconfig = tq.get_default_qconfig('qnnpack')

# %%
# from torchsummary import summary
# summary(model, (3, 192, 256), device='cpu')
model
# Out:
# PoseMobileNet(
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): ConvReLU2d(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1))
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): ConvReLU2d(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960)
#             (1): ReLU(inplace=True)
#           )
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1))
#         (3): Identity()
#       )
#       (skip_add): FloatFunctional(
#         (activation_post_process): Identity()
#       )
#     )
#     (18): ConvBNReLU(
#       (0): ConvReLU2d(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#       )
#       (1): Identity()
#       (2): Identity()
#     )
#   )
#   (conv_transpose_layers): Sequential(
#     (0): ConvTranspose2d(1280, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#   )
#   (final_layer): Conv2d(128, 21, kernel_size=(1, 1), stride=(1, 1))
#   (quant): QuantStub()
#   (dequant): DeQuantStub()
# )

# %%
N = 16
C = 3
H, W = 192, 256
x = torch.randn(N, C, H, W)
qx = quantize(x, torch.quint8)

SNR(x, qx)
# Out:
# (7934.060356838403, 38.994954999624525)

# %%
import copy

# Create quantized model
model_prepared = tq.prepare(model, inplace=False)
model_calibrated = copy.deepcopy(model_prepared)
model_calibrated(x);
model_converted = tq.convert(model_calibrated, inplace=False)

# %%
model_converted
# Out:
# PoseMobileNet(
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): QuantizedConvReLU2d(3, 32, kernel_size=(3, 3), stride=(2, 2), scale=0.009284310974180698, zero_point=0, padding=(1, 1))
#       (1): Identity()
#       (2): Identity()
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(32, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.004920272622257471, zero_point=0, padding=(1, 1), groups=32)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): QuantizedConv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), scale=0.0030450373888015747, zero_point=113)
#         (2): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(16, 96, kernel_size=(1, 1), stride=(1, 1), scale=0.001046488992869854, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(96, 96, kernel_size=(3, 3), stride=(2, 2), scale=0.0006432635709643364, zero_point=0, padding=(1, 1), groups=96)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), scale=0.000336145720211789, zero_point=126)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(24, 144, kernel_size=(1, 1), stride=(1, 1), scale=0.00010891144484048709, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(144, 144, kernel_size=(3, 3), stride=(1, 1), scale=5.85980924370233e-05, zero_point=0, padding=(1, 1), groups=144)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), scale=2.6154220904572867e-05, zero_point=126)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=0.0003325595462229103, zero_point=123
#         (activation_post_process): Identity()
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(24, 144, kernel_size=(1, 1), stride=(1, 1), scale=0.00010194917558692396, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(144, 144, kernel_size=(3, 3), stride=(2, 2), scale=7.166683644754812e-05, zero_point=0, padding=(1, 1), groups=144)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), scale=4.0568498661741614e-05, zero_point=136)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(32, 192, kernel_size=(1, 1), stride=(1, 1), scale=1.174868975795107e-05, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(192, 192, kernel_size=(3, 3), stride=(1, 1), scale=7.835820724721998e-06, zero_point=0, padding=(1, 1), groups=192)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), scale=2.844315304173506e-06, zero_point=122)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=4.106649794266559e-05, zero_point=136
#         (activation_post_process): Identity()
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(32, 192, kernel_size=(1, 1), stride=(1, 1), scale=1.5402745702886023e-05, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(192, 192, kernel_size=(3, 3), stride=(1, 1), scale=5.975843123451341e-06, zero_point=0, padding=(1, 1), groups=192)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), scale=2.542700713092927e-06, zero_point=121)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=4.1213901567971334e-05, zero_point=135
#         (activation_post_process): Identity()
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(32, 192, kernel_size=(1, 1), stride=(1, 1), scale=1.2233059351274278e-05, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(192, 192, kernel_size=(3, 3), stride=(2, 2), scale=9.076825335796457e-06, zero_point=0, padding=(1, 1), groups=192)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), scale=3.194738837919431e-06, zero_point=141)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(64, 384, kernel_size=(1, 1), stride=(1, 1), scale=1.002551812234742e-06, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(384, 384, kernel_size=(3, 3), stride=(1, 1), scale=7.999263971214532e-07, zero_point=0, padding=(1, 1), groups=384)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), scale=2.5028180061781313e-07, zero_point=110)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=3.0761918878852157e-06, zero_point=143
#         (activation_post_process): Identity()
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(64, 384, kernel_size=(1, 1), stride=(1, 1), scale=1.1125381433885195e-06, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(384, 384, kernel_size=(3, 3), stride=(1, 1), scale=8.607152039985522e-07, zero_point=0, padding=(1, 1), groups=384)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), scale=2.951208273316297e-07, zero_point=145)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=3.089391384492046e-06, zero_point=143
#         (activation_post_process): Identity()
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(64, 384, kernel_size=(1, 1), stride=(1, 1), scale=9.593686627340503e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(384, 384, kernel_size=(3, 3), stride=(1, 1), scale=4.853208110944252e-07, zero_point=0, padding=(1, 1), groups=384)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), scale=2.594953514289955e-07, zero_point=138)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=3.1246781873051077e-06, zero_point=142
#         (activation_post_process): Identity()
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(64, 384, kernel_size=(1, 1), stride=(1, 1), scale=1.083053234651743e-06, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(384, 384, kernel_size=(3, 3), stride=(1, 1), scale=6.693264253954112e-07, zero_point=0, padding=(1, 1), groups=384)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), scale=2.7681551273417426e-07, zero_point=132)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(96, 576, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(576, 576, kernel_size=(3, 3), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), groups=576)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=24)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=2.8647798444580985e-07, zero_point=134
#         (activation_post_process): Identity()
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(96, 576, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(576, 576, kernel_size=(3, 3), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), groups=576)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=25)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=2.775351504169521e-07, zero_point=132
#         (activation_post_process): Identity()
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(96, 576, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(576, 576, kernel_size=(3, 3), stride=(2, 2), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), groups=576)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=28)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(160, 960, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(960, 960, kernel_size=(3, 3), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), groups=960)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=3)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.1920928955078125e-07, zero_point=29
#         (activation_post_process): Identity()
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(160, 960, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(960, 960, kernel_size=(3, 3), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), groups=960)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=2)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.1920928955078125e-07, zero_point=29
#         (activation_post_process): Identity()
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): QuantizedConvReLU2d(160, 960, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#           (1): Identity()
#           (2): Identity()
#         )
#         (1): ConvBNReLU(
#           (0): QuantizedConvReLU2d(960, 960, kernel_size=(3, 3), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), groups=960)
#           (1): Identity()
#           (2): Identity()
#         )
#         (2): QuantizedConv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=3)
#         (3): Identity()
#       )
#       (skip_add): QFunctional(
#         scale=1.0, zero_point=0
#         (activation_post_process): Identity()
#       )
#     )
#     (18): ConvBNReLU(
#       (0): QuantizedConvReLU2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), scale=1.1920928955078125e-07, zero_point=0)
#       (1): Identity()
#       (2): Identity()
#     )
#   )
#   (conv_transpose_layers): Sequential(
#     (0): QuantizedConvTranpose2d(1280, 128, kernel_size=(4, 4), stride=(2, 2), scale=1.1920928955078125e-07, zero_point=1, padding=(1, 1), bias=False)
#     (1): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): QuantizedReLU(inplace=True)
#     (3): QuantizedConvTranpose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), bias=False)
#     (4): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): QuantizedReLU(inplace=True)
#     (6): QuantizedConvTranpose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), scale=1.1920928955078125e-07, zero_point=0, padding=(1, 1), bias=False)
#     (7): QuantizedBatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): QuantizedReLU(inplace=True)
#   )
#   (final_layer): QuantizedConv2d(128, 21, kernel_size=(1, 1), stride=(1, 1), scale=0.0005996405961923301, zero_point=119)
#   (quant): Quantize(scale=tensor([0.0307]), zero_point=tensor([128]), dtype=torch.quint8)
#   (dequant): DeQuantize()
# )

# %%
y = model(x)
qy = model_converted(x)

print("SNR: {}, SNR(dB): {}".format(*SNR(y, qy)))
# Out:
# SNR: 72752.96636753932, SNR(dB): 48.6185070557258
